# %% [markdown]
# ## Installing needed libraries
# Restart kernel after installation

# %%
# !pip install transformers
# !pip install tensorflow-text
# Out:
# Collecting transformers
#   Downloading transformers-4.16.2-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 5.3 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 53.5 MB/s
# Collecting tokenizers!=0.11.3,>=0.10.1
#   Downloading tokenizers-0.11.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 39.0 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.6 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 70.1 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.47 tokenizers-0.11.5 transformers-4.16.2
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.8.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 5.3 MB/s
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text) (0.12.0)
# Requirement already satisfied: tensorflow<2.9,>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (57.4.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (0.5.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (1.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (3.17.3)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (1.43.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (1.0.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 45.9 MB/s
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (0.24.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (1.13.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (13.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (3.10.0.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (1.21.5)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.9,>=2.8.0->tensorflow-text) (3.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<2.9,>=2.8.0->tensorflow-text) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<2.9,>=2.8.0->tensorflow-text) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (4.11.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9,>=2.8.0->tensorflow-text) (3.2.0)
# Installing collected packages: tf-estimator-nightly, tensorflow-text
# Successfully installed tensorflow-text-2.8.1 tf-estimator-nightly-2.8.0.dev2021122109

# %% [markdown]
# ## Imports
# Next, we need to import all the needed libraries

# %%
import random
import keras
import tensorflow_text
import sklearn.metrics as metrics
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import train_test_split
import tensorflow_hub as hub
from matplotlib import pyplot as plt
from keras.models import Sequential, Model
from keras.layers import Dense, Input
from keras import backend as K
import pandas as pd
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Reading the data
# We read the main dataset from the imported csv file.

# %%
data = pd.read_csv("http://modelingcreativity.org/data/aut_categorizedRaters.csv", encoding = 'latin-1')

# %%
data.head()
# Out:
#   research_id  response_id  respondent_id object  ... C60 C61  C62  C63
# 0   CES201610      10063.0            648  brick  ...   0   0    0    0
# 1   CES201610       5801.0            363  brick  ...   0   0    0    0
# 2   CES201610       3973.0            237  brick  ...   0   0    0    0
# 3   CES201610       5226.0            300  brick  ...   0   0    0    0
# 4   CES201610       8321.0            555  brick  ...   0   0    0    0
#
# [5 rows x 70 columns]

# %% [markdown]
# We read the data from the raters' files.

# %%
raters_1 = pd.read_csv('http://modelingcreativity.org/data/brickcat_rater1.csv', encoding = 'latin-1').drop_duplicates(['original_response'])
responses_1 = raters_1['original_response'].to_list()
targets_1 = np.array([raters_1["cat_"+str(i)].to_list() for i in range(64)]).T

# %%
raters_2 = pd.read_csv('http://modelingcreativity.org/data/brickcat_rater2.csv', encoding = 'latin-1').drop_duplicates(['original_response'])
responses_2 = raters_2['original_response'].to_list()
targets_2 = np.array([raters_2["cat_"+str(i)].to_list() for i in range(64)]).T

# %%
raters_3 = pd.read_csv('http://modelingcreativity.org/data/brickcat_rater3.csv', encoding = 'latin-1').drop_duplicates(['original_response'])
responses_3 = raters_3['original_response'].to_list()
targets_3 = np.array([raters_3["cat_"+str(i)].to_list() for i in range(64)]).T

# %%
len(responses_1)
# Out:
# 755

# %% [markdown]
# Extract only the responses that are not in the raters' datasets to feed into the algorithm.

# %%
remaining_data = data[~data['original_response'].isin(responses_1+responses_2+responses_3).to_numpy()]

# %%
remaining_data.shape
# Out:
# (4467, 70)

# %%
responses = remaining_data['original_response'].to_list()
categories = np.array([remaining_data["C"+str(i)].to_list() for i in range(64)]).T

# %%
## This can be used instead if you don't want to remove any of the responses from the main dataframe
#responses = data['original_response'].to_list()
#categories = np.array([data["C"+str(i)].to_list() for i in range(64)]).T

# %%
len(responses)
#remaining number of responses to be used
# Out:
# 4467

# %% [markdown]
# ## Loading the model and generating embeddings

# %%
module     = hub.load('https://tfhub.dev/google/universal-sentence-encoder-multilingual-large/3')

embeddings = module(responses)

# %%
X = embeddings.numpy()
y = categories

# %% [markdown]
# ## Saving embeddings to disk

# %%
np.save('X',X)
np.save('y',y)

# %%
X = np.load('X.npy')
y = np.load('y.npy')

# %%
X.shape,y.shape
# Out:
# ((4467, 512), (4467, 64))

# %% [markdown]
# ## Train test split

# %% [markdown]
# Divide into training (90%) and testing (10%) set, so that we have a set to test the final model's unbiased performance. The training set is further divided into a training (90%) and validation (10%) set to find the best model. We shuffle the data to get a random split, and also set a seed for reproducability.

# %%
X_interm, X_test, y_interm, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42, shuffle=True)

X_train, X_val, y_train, y_val = train_test_split(
    X_interm, y_interm, test_size=0.1, random_state=42, shuffle=True)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((3618, 512), (402, 512), (447, 512))

# %% [markdown]
# ## Training a simple neural network

# %% [markdown]
# ### Defining metrics

# %% [markdown]
# Create an f1 score function to add as a metric to the keras NN, as it is not available by default.

# %%
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ### Training parameters

# %%
LEARNING_RATE = 0.1 #@param {type:"number"}
BATCH_SIZE = 256 #@param {type:"integer"}
EPOCHS = 40 #@param {type:"integer"}

# %% [markdown]
# ### Defining model

# %%
def model_function ():
  global LEARNING_RATE
  inputs = Input(shape=(512,), name='inputs', dtype='float')
  output = Dense(64, activation = 'sigmoid')(inputs)
  model = Model(inputs= inputs, outputs=output, name='USE_MultiLabel')
  model.compile(loss='binary_crossentropy', optimizer = tf.keras.optimizers.Adam(LEARNING_RATE), metrics=['categorical_accuracy',f1])
  return model

# %% [markdown]
# ### Train look

# %%
model = model_function ()
history = model.fit(X_train,y_train, validation_data = (X_val, y_val), epochs = EPOCHS, batch_size = BATCH_SIZE)
# Out:
# Epoch 1/40
# 15/15 [==============================] - 1s 26ms/step - loss: 0.1421 - categorical_accuracy: 0.3494 - f1: 0.2975 - val_loss: 0.0578 - val_categorical_accuracy: 0.5174 - val_f1: 0.4305
# Epoch 2/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0543 - categorical_accuracy: 0.5522 - f1: 0.5448 - val_loss: 0.0445 - val_categorical_accuracy: 0.6095 - val_f1: 0.5889
# Epoch 3/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0423 - categorical_accuracy: 0.6515 - f1: 0.6307 - val_loss: 0.0371 - val_categorical_accuracy: 0.6816 - val_f1: 0.6727
# Epoch 4/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0351 - categorical_accuracy: 0.7001 - f1: 0.6659 - val_loss: 0.0331 - val_categorical_accuracy: 0.7090 - val_f1: 0.6965
# Epoch 5/40
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0306 - categorical_accuracy: 0.7463 - f1: 0.7132 - val_loss: 0.0317 - val_categorical_accuracy: 0.7239 - val_f1: 0.7203
# Epoch 6/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0279 - categorical_accuracy: 0.7645 - f1: 0.7255 - val_loss: 0.0309 - val_categorical_accuracy: 0.7264 - val_f1: 0.7196
# Epoch 7/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0260 - categorical_accuracy: 0.7794 - f1: 0.7432 - val_loss: 0.0302 - val_categorical_accuracy: 0.7214 - val_f1: 0.7213
# Epoch 8/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0244 - categorical_accuracy: 0.7957 - f1: 0.7532 - val_loss: 0.0294 - val_categorical_accuracy: 0.7363 - val_f1: 0.7318
# Epoch 9/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0231 - categorical_accuracy: 0.8115 - f1: 0.7627 - val_loss: 0.0292 - val_categorical_accuracy: 0.7413 - val_f1: 0.7404
# Epoch 10/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0220 - categorical_accuracy: 0.8198 - f1: 0.7775 - val_loss: 0.0291 - val_categorical_accuracy: 0.7537 - val_f1: 0.7477
# Epoch 11/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0211 - categorical_accuracy: 0.8167 - f1: 0.7879 - val_loss: 0.0293 - val_categorical_accuracy: 0.7313 - val_f1: 0.7438
# Epoch 12/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0201 - categorical_accuracy: 0.8284 - f1: 0.7958 - val_loss: 0.0289 - val_categorical_accuracy: 0.7388 - val_f1: 0.7477
# Epoch 13/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0193 - categorical_accuracy: 0.8364 - f1: 0.8012 - val_loss: 0.0285 - val_categorical_accuracy: 0.7463 - val_f1: 0.7462
# Epoch 14/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0187 - categorical_accuracy: 0.8355 - f1: 0.8115 - val_loss: 0.0288 - val_categorical_accuracy: 0.7512 - val_f1: 0.7433
# Epoch 15/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0180 - categorical_accuracy: 0.8427 - f1: 0.8155 - val_loss: 0.0289 - val_categorical_accuracy: 0.7463 - val_f1: 0.7503
# Epoch 16/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0174 - categorical_accuracy: 0.8496 - f1: 0.8203 - val_loss: 0.0288 - val_categorical_accuracy: 0.7512 - val_f1: 0.7550
# Epoch 17/40
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0168 - categorical_accuracy: 0.8521 - f1: 0.8185 - val_loss: 0.0287 - val_categorical_accuracy: 0.7562 - val_f1: 0.7581
# Epoch 18/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0165 - categorical_accuracy: 0.8535 - f1: 0.8248 - val_loss: 0.0290 - val_categorical_accuracy: 0.7537 - val_f1: 0.7435
# Epoch 19/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0160 - categorical_accuracy: 0.8596 - f1: 0.8376 - val_loss: 0.0291 - val_categorical_accuracy: 0.7488 - val_f1: 0.7516
# Epoch 20/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0156 - categorical_accuracy: 0.8618 - f1: 0.8429 - val_loss: 0.0288 - val_categorical_accuracy: 0.7537 - val_f1: 0.7655
# Epoch 21/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0151 - categorical_accuracy: 0.8682 - f1: 0.8437 - val_loss: 0.0290 - val_categorical_accuracy: 0.7537 - val_f1: 0.7584
# Epoch 22/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0146 - categorical_accuracy: 0.8682 - f1: 0.8502 - val_loss: 0.0289 - val_categorical_accuracy: 0.7537 - val_f1: 0.7536
# Epoch 23/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0142 - categorical_accuracy: 0.8751 - f1: 0.8515 - val_loss: 0.0292 - val_categorical_accuracy: 0.7562 - val_f1: 0.7496
# Epoch 24/40
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0140 - categorical_accuracy: 0.8753 - f1: 0.8613 - val_loss: 0.0291 - val_categorical_accuracy: 0.7637 - val_f1: 0.7470
# Epoch 25/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0136 - categorical_accuracy: 0.8778 - f1: 0.8549 - val_loss: 0.0291 - val_categorical_accuracy: 0.7537 - val_f1: 0.7511
# Epoch 26/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0133 - categorical_accuracy: 0.8765 - f1: 0.8652 - val_loss: 0.0293 - val_categorical_accuracy: 0.7587 - val_f1: 0.7570
# Epoch 27/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0129 - categorical_accuracy: 0.8839 - f1: 0.8696 - val_loss: 0.0295 - val_categorical_accuracy: 0.7512 - val_f1: 0.7518
# Epoch 28/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0126 - categorical_accuracy: 0.8875 - f1: 0.8703 - val_loss: 0.0297 - val_categorical_accuracy: 0.7562 - val_f1: 0.7518
# Epoch 29/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0125 - categorical_accuracy: 0.8875 - f1: 0.8691 - val_loss: 0.0294 - val_categorical_accuracy: 0.7587 - val_f1: 0.7549
# Epoch 30/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0122 - categorical_accuracy: 0.8867 - f1: 0.8751 - val_loss: 0.0297 - val_categorical_accuracy: 0.7512 - val_f1: 0.7661
# Epoch 31/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0119 - categorical_accuracy: 0.8917 - f1: 0.8786 - val_loss: 0.0300 - val_categorical_accuracy: 0.7612 - val_f1: 0.7545
# Epoch 32/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0117 - categorical_accuracy: 0.8925 - f1: 0.8847 - val_loss: 0.0298 - val_categorical_accuracy: 0.7662 - val_f1: 0.7667
# Epoch 33/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0114 - categorical_accuracy: 0.8919 - f1: 0.8854 - val_loss: 0.0301 - val_categorical_accuracy: 0.7562 - val_f1: 0.7506
# Epoch 34/40
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0112 - categorical_accuracy: 0.8983 - f1: 0.8887 - val_loss: 0.0300 - val_categorical_accuracy: 0.7587 - val_f1: 0.7589
# Epoch 35/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0111 - categorical_accuracy: 0.8930 - f1: 0.8926 - val_loss: 0.0301 - val_categorical_accuracy: 0.7612 - val_f1: 0.7538
# Epoch 36/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0108 - categorical_accuracy: 0.8988 - f1: 0.8919 - val_loss: 0.0302 - val_categorical_accuracy: 0.7587 - val_f1: 0.7544
# Epoch 37/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0106 - categorical_accuracy: 0.8997 - f1: 0.8954 - val_loss: 0.0304 - val_categorical_accuracy: 0.7687 - val_f1: 0.7593
# Epoch 38/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0106 - categorical_accuracy: 0.9035 - f1: 0.8927 - val_loss: 0.0305 - val_categorical_accuracy: 0.7512 - val_f1: 0.7626
# Epoch 39/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0104 - categorical_accuracy: 0.8994 - f1: 0.9008 - val_loss: 0.0306 - val_categorical_accuracy: 0.7537 - val_f1: 0.7623
# Epoch 40/40
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0102 - categorical_accuracy: 0.9019 - f1: 0.8975 - val_loss: 0.0310 - val_categorical_accuracy: 0.7687 - val_f1: 0.7488

# %% [markdown]
# ## Visualization of results

# %%
plt.plot(history.history['f1'])
plt.plot(history.history['val_f1'])
plt.title('USE + NN model F1 score (original response dataset)')
plt.ylabel('F1')
plt.xlabel('Epoch')
plt.legend(['training F1', 'validation F1'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('USE + NN model loss (original response dataset)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['training loss', 'validation loss'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluation on the validation set

# %%
predictions = model.predict(X_val)
predictions = (predictions > 0.5)
accuracy   = accuracy_score(y_val, predictions)
precision  = precision_score(y_val, predictions, average = 'micro')
recall     = recall_score(y_val, predictions, average = 'micro')
f1_        = f1_score(y_val, predictions, average = 'micro')
hl         = hamming_loss(y_val, predictions)

print("Accuracy:", round(accuracy, 3))
print("Precision:", round(precision, 3))
print("Recall:", round(recall, 3))
print("F-1:", round(f1_, 3))
print("Hamming Loss:", round(hl, 5))
# Out:
# Accuracy: 0.652
# Precision: 0.801
# Recall: 0.686
# F-1: 0.739
# Hamming Loss: 0.00828

# %% [markdown]
# ## Evaluation on the test set

# %%
predictions = model.predict(X_test)
predictions = (predictions > 0.5) 

accuracy   = accuracy_score(y_test, predictions)
precision  = precision_score(y_test, predictions, average = 'micro')
recall     = recall_score(y_test, predictions, average = 'micro')
f1_        = f1_score(y_test, predictions, average = 'micro')
hl         = hamming_loss(y_test, predictions)

print("Accuracy:", round(accuracy, 3))
print("Precision:", round(precision, 3))
print("Recall:", round(recall, 3))
print("F-1:", round(f1_, 3))
print("Hamming Loss:", round(hl, 5))
# Out:
# Accuracy: 0.638
# Precision: 0.818
# Recall: 0.658
# F-1: 0.729
# Hamming Loss: 0.00853

# %%
## Print the precision, recall, and f1-score for each category (0 to 63)
test_report = metrics.classification_report(y_test, predictions, digits=3)
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0      0.781     0.595     0.676        42
#            1      0.953     0.879     0.915       116
#            2      0.867     0.867     0.867        15
#            3      1.000     0.250     0.400         4
#            4      0.500     0.333     0.400         3
#            5      0.800     0.800     0.800        20
#            6      0.250     0.118     0.160        17
#            7      0.833     1.000     0.909        10
#            8      1.000     0.600     0.750         5
#            9      1.000     0.750     0.857         4
#           10      1.000     1.000     1.000         1
#           11      0.700     0.824     0.757        17
#           12      0.750     0.750     0.750         4
#           13      0.857     0.375     0.522        16
#           14      1.000     1.000     1.000         4
#           15      1.000     1.000     1.000         2
#           16      0.000     0.000     0.000         1
#           17      0.846     0.786     0.815        14
#           18      0.000     0.000     0.000         1
#           19      0.000     0.000     0.000         2
#           20      0.625     0.556     0.588         9
#           21      1.000     0.250     0.400         8
#           22      1.000     0.429     0.600         7
#           23      0.875     1.000     0.933        14
#           24      0.000     0.000     0.000         0
#           25      0.000     0.000     0.000         1
#           26      0.889     0.727     0.800        22
#           27      0.000     0.000     0.000         2
#           28      0.895     0.708     0.791        24
#           29      1.000     0.818     0.900        11
#           30      0.000     0.000     0.000         0
#           31      0.000     0.000     0.000         0
#           32      0.800     0.800     0.800         5
#           33      0.000     0.000     0.000         1
#           34      0.000     0.000     0.000         3
#           35      0.000     0.000     0.000         3
#           36      1.000     1.000     1.000         3
#           37      0.000     0.000     0.000         1
#           38      0.571     0.800     0.667         5
#           39      0.500     0.500     0.500         2
#           40      0.667     0.500     0.571         8
#           41      0.000     0.000     0.000         1
#           42      0.000     0.000     0.000         1
#           43      1.000     0.500     0.667         2
#           44      0.000     0.000     0.000         0
#           45      0.000     0.000     0.000         1
#           46      0.000     0.000     0.000         0
#           47      0.667     0.667     0.667         3
#           48      0.833     0.714     0.769         7
#           49      1.000     0.600     0.750         5
#           50      0.500     0.333     0.400         3
#           51      0.625     0.556     0.588         9
#           52      0.500     0.167     0.250         6
#           53      0.500     0.200     0.286        10
#           54      1.000     0.500     0.667         2
#           55      0.000     0.000     0.000         1
#           56      1.000     0.500     0.667         2
#           57      1.000     0.750     0.857         8
#           58      0.500     0.250     0.333         4
#           59      0.000     0.000     0.000         3
#           60      0.200     0.333     0.250         3
#           61      0.000     0.000     0.000         0
#           62      0.000     0.000     0.000         1
#           63      0.000     0.000     0.000         1
#
#    micro avg      0.818     0.658     0.729       500
#    macro avg      0.520     0.408     0.442       500
# weighted avg      0.785     0.658     0.702       500
#  samples avg      0.696     0.694     0.688       500
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
fig, ax = plt.subplots(figsize=(30, 30))
cm = metrics.ConfusionMatrixDisplay.from_predictions(y_test.argmax(axis=1), predictions.argmax(axis=1), ax=ax, normalize = 'true')

# %% [markdown]
# ## Rater vs Rater Comparison

# %% [markdown]
# Hamming loss scores for all raters between each other.

# %%
# Rater 1 vs Rater 2
rater01_02   = hamming_loss(targets_1, targets_2)

# Rater 1 vs Rater 3
rater01_03   = hamming_loss(targets_1, targets_3)

# Rater 2 vs Rater 3
rater02_03   = hamming_loss(targets_2, targets_3)

print("Rater 1 vs Rater 2:")
print("Hamming Loss:", round(rater01_02, 5))
print()
print("Rater 1 vs Rater 3:")
print("Hamming Loss:", round(rater01_03, 5))
print()
print("Rater 2 vs Rater 3:")
print("Hamming Loss:", round(rater02_03, 5))
# Out:
# Rater 1 vs Rater 2:
# Hamming Loss: 0.02713
#
# Rater 1 vs Rater 3:
# Hamming Loss: 0.02945
#
# Rater 2 vs Rater 3:
# Hamming Loss: 0.02533

# %% [markdown]
# ## Rater vs USE + NN Algorithm

# %% [markdown]
# Evaluation of the USE + NN algorithm using predictions based on the raters' sets. Hamming loss scores between each rater's category codings and the algorithm predictions of the categories based on the responses in the raters' files are extracted.

# %%
embeddings_1 = module(responses_1)
embeddings_2 = module(responses_2)
embeddings_3 = module(responses_3)

# %%
predictions_1 = model.predict(embeddings_1.numpy())
predictions_1 = (predictions_1 > 0.5) 

predictions_2 = model.predict(embeddings_2.numpy())
predictions_2 = (predictions_2 > 0.5) 

predictions_3 = model.predict(embeddings_3.numpy())
predictions_3 = (predictions_3 > 0.5)

# %%
# Rater 1 vs Algorithm
rater01_hl = hamming_loss(targets_1, predictions_1)

# Rater 1 vs Algorithm
rater02_hl = hamming_loss(targets_2, predictions_2)

# Rater 3 vs Algorithm
rater03_hl = hamming_loss(targets_3, predictions_3)


print("Rater 1 vs Algorithm:", round(rater01_hl, 5))
print("Rater 2 vs Algorithm:", round(rater02_hl, 5))
print("Rater 3 vs Algorithm:", round(rater03_hl, 5))
# Out:
# Rater 1 vs Algorithm: 0.03092
# Rater 2 vs Algorithm: 0.02655
# Rater 3 vs Algorithm: 0.02448
